# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# #plotting

# %%
img1=cv2.imread("Resources/image1/img1.jpg",0)

# %%
plt.imshow(img1)

# %% [markdown]
# #arithmatic operations

# %%
img2=cv2.imread("Resources/image1/img2.jpg",0)

# %% [markdown]
# #addition

# %%
result=img1+img2

# %%
plt.imshow(result)

# %% [markdown]
# #subtraction

# %%
result=img1-img2

# %%
plt.imshow(result)

# %% [markdown]
# #multiplication

# %%
result=img1*img2
plt.imshow(result)

# %% [markdown]
# #division

# %%
result=img1/img2
plt.imshow(result)

# %% [markdown]
# #blurring the image

# %%
img1=cv2.imread("Resources/image1/img3.jpg")
#convert the color
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("Blurred")
plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# #zoom in

# %%
img1=cv2.imread("Resources/image1/img1.jpg")

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %% [markdown]
# another way of zoom

# %%
zoom=cv2.resize(img1,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img1,(int(width/2),int(height/2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %% [markdown]
# #rotating the image

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),90,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %% [markdown]
# translate the image

# %%
import numpy as np

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))
plt.imshow(dst)
